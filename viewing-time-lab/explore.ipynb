# %% [markdown]
# ## 1. Clean your Datasets
#
# For the first part of your project, you will apply the same data cleaning steps to your "data/control.txt" and "data/treatment.txt" files. By the end of this step, you should have two lists of floats that match the numbers you have in each respective file.
#
# You will implement your `clean_data` function in your `cleaner.py` module and import the module in the code-block below.

# %%
# TODO: import all the packages that you will need for this notebook here
import statistics as stats
import matplotlib.pyplot as plt
import numpy as np

import cleaner

# %%
# TODO: read your text files into your code using file I/O
control_file = open("data/control.txt")
treatment_file = open("data/treatment.txt")

treatment_data = treatment_file.readlines()
control_data = control_file.readlines()

# TODO: clean both list objects that you created above using the 'clean_data' function
control_data = cleaner.clean_data(control_data)
treatment_data = cleaner.clean_data(treatment_data)

# %% [markdown]
# ## 2. Explore your Datasets
#
# Now that you have your list objects created and cleaned, let's explore the descriptive statistics of these two files and make subsequent observations on our data.

# %%
# TODO: Calculate the standard deviation of both the control and treatment group
std_control = stats.stdev(control_data)
std_treatment = stats.stdev(treatment_data)

# TODO: print your findings
print("Standard Deviation for Control: ", std_control)
print("Standard Deviation for Treatment: ",std_treatment)
# Out:
# Standard Deviation for Control:  3.2617527483828637
# Standard Deviation for Treatment:  2.0859812341001622

# %%
# TODO: Calculate the mean of both the control and treatment group
avg_control = stats.mean(control_data)
avg_treatment = stats.mean(treatment_data)

# TODO: print your findings
print("Average Time for Control: ", avg_control) # 
print("Average Time for Treatment: ", avg_treatment) # 16.8 mins increase. increase viewing time by 4 minutes
# Out:
# Average Time for Control:  12.45052
# Average Time for Treatment:  16.79708

# %%
# TODO: Are there any outliers in your control group? (use 2 * stdev to find these outliers)
outliers_control = []
for out in control_data:
    if out<6 or out>18:
       outliers_control.append(out)
print(outliers_control)
# Out:
# [5.97, 5.92, 4.36, 18.85, 18.3, 4.21, 20.2, 3.69, 3.83, 21.21, 5.07, 18.15, 4.87, 5.28, 5.75, 18.63, 20.18, 18.46, 20.95, 4.12, 18.21, 19.21, 18.25, 5.51, 4.01, 20.57, 20.72, 5.99, 18.27, 3.71]

# %%
# TODO: Are there any outliers in your treatment group?
outliers_treatment = []
for num in treatment_data:
    if num <12.62 or num > 20.96:
        outliers_treatment.append(num)

print(outliers_treatment)
# Out:
# [21.17, 10.34, 21.07, 11.54, 21.66, 22.11, 12.02, 12.41, 11.35, 22.85, 21.49, 11.99, 21.57, 21.76, 12.54, 12.53, 12.34, 12.32, 21.42, 10.33]

# %% [markdown]
# ## 3. Create Data Visualizations
#
# For this final step, generate data visualizations to view the dispersion of both of your groups.
#
# Make sure that the two visualizations you create are on the same figure.

# %%
# TODO: create a data visualization to view differences in dispersion and mean
fig, axes = plt.subplots(1,2)
axes[0].boxplot(control_data)
axes[1].boxplot(treatment_data)
axes[0].set_title("Control Group")
axes[1].set_title("Treatment Group")
axes[0].set_xlabel("Group")
axes[0].set_ylabel("Viewing Time(mins)")
axes[1].set_xlabel("Group")
axes[1].set_ylabel("Viewing Time(mins)")
plt.show()

# %% [markdown]
# ## 4. Your Data Findings
#
# What did you discover about your two datasets? Which group has the highest viewing time? What would you want to investigate next?

# %% [markdown]
# Your answer here

# %% [markdown]
# *** In completing my data analysis I learned that the standard deviation for control group is higher than the treatment group but the average time for treatment group was 4 minutes higher showing that less words on the slides had an impact on the viewing time. I would also like to further investigate why some people in the  treatment groups were  more receptive than others. I noticed that  the treatment group had outliers on both the high and low end — meaning the treatment didn't affect everyone the same way. I believe some people responded better to the treatment than others, and that factors like age, device type, or time of day could explain why!
